# %%
from music21 import *
star = converter.parse('tinyNotation: 4/4 c4 c g g a a g2 f4 f e e d d c2')
# star.show()
star.write('midi', 'twinkle_twinkle_melody.mid')
# Out:
# 'twinkle_twinkle_melody.mid'

# %%
new_start = converter.parse('./twinkle_twinkle_melody.mid')
new_start.show()

# %%
from music21 import *

converter.parse('./../bachbot/soundcloud/Cmaj-harm.mscz').show()
# Out:
# ---------------------------------------------------------------------------
# ConverterFileException                    Traceback (most recent call last)
# /home/tbushnell/GitHub/Singing-AI-Bach/models/magenta/test.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell://tunnel%2Btrevor-pc/home/tbushnell/GitHub/Singing-AI-Bach/models/magenta/test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from music21 import *
# ----> <a href='vscode-notebook-cell://tunnel%2Btrevor-pc/home/tbushnell/GitHub/Singing-AI-Bach/models/magenta/test.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> converter.parse('./../bachbot/soundcloud/Cmaj-harm.mscz').show()
#
# File ~/miniconda3/envs/guchoirs/lib/python3.9/site-packages/music21/converter/__init__.py:1297, in parse(value, forceSource, number, format, **keywords)
#    1294     return parseData(value, number=number, format=format, **keywords)
#    1295 elif (not isinstance(value, bytes)
#    1296       and _osCanLoad(valueStr)):
# ...
